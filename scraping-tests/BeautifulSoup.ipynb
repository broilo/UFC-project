# %% [markdown]
# # Scraping data from Wikipedia

# %%
import requests
from bs4 import BeautifulSoup
import lxml.html as lh
import pandas as pd

# %% [markdown]
# ## Heavyweights (265 lb, 120 kg)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_current_UFC_fighters#Heavyweights_(265_lb,_120_kg)'

#Create a handle, page, to handle the contents of the website
page = requests.get(url)

#Store the contents of the website under doc
doc = lh.fromstring(page.content)

#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 10 rows
[len(T) for T in tr_elements[:10]]
# Out:
# [9, 9, 9, 9, 9, 9, 9, 9, 9, 9]

# %%
tr_elements = doc.xpath('//tr')

#Create empty list
col = []
i = 0

#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i += 1
    name = t.text_content()
    print('%d:"%s"'%(i, name))
    col.append((name, []))
# Out:
# 1:"Date
# "
# 2:"ISO
# "
# 3:"Name
# "
# 4:"Nickname
# "
# 5:"Reason
# "
# 6:"Division
# "
# 7:"Ref
# "
# 8:"Endeavor record
# "
# 9:"MMA record
# "

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T = tr_elements[j]    
    #If row is not of size 9, the //tr data is not from our table 
    if len(T) != 9:
        break
    #i is the index of our column
    i = 0
    #Iterate through each element of the row
    for t in T.iterchildren():
        data = t.text_content() 
        #Check if row is empty
        if i > 0:
        #Convert any numerical value to integers
            try:
                data = int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i += 1

# %%
[len(C) for (title,C) in col]
# Out:
# [57, 57, 57, 57, 57, 57, 57, 57, 57]

# %%
Dict = {title:column for (title, column) in col}
df = pd.DataFrame(Dict)

# %%
df
# Out:
#                   Date\n  ISO\n                      Name\n  \
# 0        July 19, 2020\n     \n              Joseph Duffy\n
# 1        July 26, 2020\n     \n             Peter Sobotta\n
# 2        July 26, 2020\n     \n         Fabrício Werdum *\n
# 3        July 26, 2020\n     \n  Antônio Rogério Nogueira\n
# 4       August 3, 2020\n     \n              Eric Spicely\n
# 5       August 8, 2020\n     \n            Corey Anderson\n
# 6       August 8, 2020\n     \n                  Ray Borg\n
# 7      August 10, 2020\n     \n             Roman Bogatov\n
# 8      August 10, 2020\n     \n               Tai Tuivasa\n
# 9                 Date\n  ISO\n                      Name\n
# 10    October 28, 2018\n     \n             Sergio Giglio\n
# 11      March 29, 2019\n     \n               Eric Wisely\n
# 12       April 3, 2019\n     \n             Melissa Gatto\n
# 13        May 13, 2019\n     \n        Salimgerey Rasulov\n
# 14        May 16, 2019\n     \n               Bruno Silva\n
# 15       June 16, 2019\n     \n             Giacomo Lemos\n
# 16       June 17, 2019\n     \n             Vince Murdock\n
# 17       June 26, 2019\n     \n              Istela Nunes\n
# 18       July 31, 2019\n     \n         Shavkat Rakhmonov\n
# 19     August 13, 2019\n     \n               Sarah Alpar\n
# 20     August 21, 2019\n     \n               Philip Rowe\n
# 21     August 23, 2019\n     \n               Lü Zhenhong\n
# 22     August 28, 2019\n     \n           Duško Todorović\n
# 23  September 26, 2019\n     \n         Alexander Romanov\n
# 24  September 26, 2019\n     \n           Chi Lewis-Parry\n
# 25  September 27, 2019\n     \n              Uroš Jurišic\n
# 26    January 31, 2020\n     \n         Umar Nurmagomedov\n
# 27      March 15, 2020\n     \n     Aleksander Doskalchuk\n
# 28      March 30, 2020\n     \n                Manel Kape\n
# 29        May 28, 2020\n     \n           Tagir Ulanbekov\n
# 30       June 19, 2020\n     \n          Miranda Maverick\n
# 31       June 20, 2020\n     \n            Ramiz Brahimaj\n
# 32       June 23, 2020\n     \n             Daniel Pineda\n
# 33        July 5, 2020\n     \n             Kanako Murata\n
# 34        July 9, 2020\n     \n               Timo Feucht\n
# 35        July 9, 2020\n     \n             Kenneth Bergh\n
# 36       July 10, 2020\n     \n            Jorge Gonzalez\n
# 37       July 19, 2020\n     \n              Ilia Topuria\n
# 38       July 21, 2020\n     \n              Timur Valiev\n
# 39       July 27, 2020\n     \n         Guram Kutateladze\n
# 40      August 4, 2020\n     \n              Danny Chavez\n
# 41      August 4, 2020\n     \n               Sarah Alpar\n
# 42      August 4, 2020\n     \n              Jared Gooden\n
# 43      August 5, 2020\n     \n             Dustin Jacoby\n
# 44      August 5, 2020\n     \n                Uros Medic\n
# 45      August 5, 2020\n     \n            Jordan Leavitt\n
# 46      August 6, 2020\n     \n             Chris Daukaus\n
# 47      August 6, 2020\n     \n             Parker Porter\n
# 48      August 8, 2020\n     \n      Matthew Semelsberger\n
# 49     August 11, 2020\n     \n            Kai Kamaka III\n
# 50     August 11, 2020\n     \n               Tony Kelley\n
# 51     August 11, 2020\n     \n           Dustin Stoltzfu\n
# 52     August 11, 2020\n     \n              Adrian Yanez\n
# 53     August 11, 2020\n     \n              Cory McKenna\n
# 54     August 11, 2020\n     \n              T.J. Laramie\n
# 55     August 11, 2020\n     \n           Impa Kasanganay\n
# 56     August 11, 2020\n     \n              Mark Striegl\n
#
#                   Nickname\n                    Reason\n  \
# 0                Irish Joe\n                   Retired\n
# 1                         \n                   Retired\n
# 2               Vai Cavalo\n         Contract finished\n
# 3   Minotouro (Little Nog)\n                   Retired\n
# 4                 Zebrinha\n                  Released\n
# 5                 Overtime\n  Signed with Bellator MMA\n
# 6     The Tazmexican Devil\n                  Released\n
# 7                         \n                  Released\n
# 8                  Bam Bam\n                  Released\n
# 9                      Ref\n                  Nickname\n
# 10                    [19]\n                  Cachorro\n
# 11                    [21]\n                Little Lee\n
# 12                    [22]\n                          \n
# 13                    [23]\n               Gubden Tank\n
# 14                    [24]\n                  Blindado\n
# 15                    [26]\n                          \n
# 16                    [28]\n                          \n
# 17                    [31]\n                          \n
# 18                    [33]\n                          \n
# 19                    [35]\n                 Too Sweet\n
# 20                    [37]\n          The Fresh Prince\n
# 21                    [39]\n                          \n
# 22                    [40]\n                          \n
# 23                    [42]\n                 King Kong\n
# 24                    [44]\n                   Chopper\n
# 25                    [44]\n                          \n
# 26                    [45]\n                          \n
# 27                    [47]\n                          \n
# 28                    [49]\n                  Prodígio\n
# 29                    [51]\n                    Gifted\n
# 30                    [53]\n                  Fear The\n
# 31                    [55]\n                          \n
# 32                    [57]\n                   The Pit\n
# 33                    [59]\n                          \n
# 34                    [60]\n                          \n
# 35                    [60]\n                      Ymir\n
# 36                    [63]\n                George St.\n
# 37                    [65]\n                          \n
# 38                    [66]\n                     Lucky\n
# 39                        \n                          \n
# 40                    [68]\n     The Colombian Warrior\n
# 41                    [70]\n                 Too Sweet\n
# 42                    [72]\n                Nite Train\n
# 43                    [74]\n                          \n
# 44                    [75]\n                          \n
# 45                    [74]\n           The Monkey King\n
# 46                    [76]\n                          \n
# 47                    [76]\n                          \n
# 48                    [77]\n                      Semi\n
# 49                    [79]\n                          \n
# 50                    [81]\n                Prime Time\n
# 51                    [83]\n                          \n
# 52                    [83]\n                          \n
# 53                    [83]\n                The Hobbit\n
# 54                    [83]\n                 The Truth\n
# 55                    [83]\n                  Tshilobo\n
# 56                    [67]\n                     Mugen\n
#
#                 Division\n                                              Ref\n  \
# 0            Lightweight\n                                             [10]\n
# 1           Welterweight\n                                             [11]\n
# 2            Heavyweight\n                                             [12]\n
# 3      Light Heavyweight\n                                             [13]\n
# 4           Middleweight\n                                             [14]\n
# 5            Heavyweight\n                                             [15]\n
# 6           Bantamweight\n                                             [16]\n
# 7            Lightweight\n                                             [17]\n
# 8            Heavyweight\n                                             [18]\n
# 9               Division\n                       Status / next fight / Info\n
# 10         Featherweight\n                                          Injured\n
# 11           Lightweight\n                                                 \n
# 12  Women's Bantamweight\n  (June 7, 2020) Visa issues - Out of UFC Fight ...
# 13           Heavyweight\n                                                 \n
# 14          Middleweight\n  (June 23, 2020) 2 years suspension by USADA fo...
# 15           Heavyweight\n  2 year USADA suspension for tested positive fo...
# 16         Featherweight\n  (1) 20 months suspension by USADA - tested pos...
# 17   Women's Strawweight\n  2 year USADA suspension for tested positive fo...
# 18          Welterweight\n  (July 3, 2020) Injury - Out of UFC Fight Night...
# 19  Women's Bantamweight\n   UFC Fight Night 178 (TBD) - Jessica-Rose Clark\n
# 20          Middleweight\n  UFC on ESPN 15 (UFC APEX) - Matthew Semelsberg...
# 21         Featherweight\n                                                 \n
# 22          Middleweight\n  (July 9, 2020) Medical issues - Out of UFC Fig...
# 23           Heavyweight\n  (July 3, 2020) Tested positive for Covid-19 - ...
# 24           Heavyweight\n                                                 \n
# 25          Welterweight\n                                                 \n
# 26         Featherweight\n  (July 3, 2020) -due to Khabib Nurmagomedov's f...
# 27             Flyweight\n  (July 11, 2020) - Undisclosed reason - Out of ...
# 28             Flyweight\n                              UFC 252 (TBD) - TBD\n
# 29             Flyweight\n  UFC Fight Night 177 (TBD) - Bruno Gustavo da S...
# 30     Women's Flyweight\n  (June 25, 2020) Injury - Out of UFC on ESPN: P...
# 31          Welterweight\n  (June 26) - one of his cornermen tested positi...
# 32         Featherweight\n                    UFC 252 (TBD) - Herbert Burns\n
# 33   Women's Strawweight\n                                                 \n
# 34     Light Heavyweight\n  (July 10, 2020) Due to past Neo-Nazi ties and ...
# 35     Light Heavyweight\n  (July 14, 2020) Berg had issue on weight cut -...
# 36     Light Heavyweight\n                 UFC 252 (TBD) - Issac Villanueva\n
# 37         Featherweight\n                                                 \n
# 38         Featherweight\n        UFC Fight Night 175 (TBD) -  Timur Valiev\n
# 39           Lightweight\n                                                 \n
# 40         Featherweight\n                        UFC 252 (TBD) -  TJ Brown\n
# 41  Women's Bantamweight\n  UFC Fight Night 179 (TBD) -  Jessica-Rose Clark\n
# 42          Welterweight\n              UFC on ESPN 15 (TBD) - Dwight Grant\n
# 43     Light Heavyweight\n                                                 \n
# 44          Welterweight\n                                                 \n
# 45           Lightweight\n                                                 \n
# 46           Heavyweight\n                    UFC 252 (TBD) - Parker Porter\n
# 47           Heavyweight\n                    UFC 252 (TBD) - Chris Daukaus\n
# 48          Middleweight\n         UFC on ESPN 15 (UFC APEX) -  Philip Rowe\n
# 49         Featherweight\n                UFC 252 (UFC APEX) -  Tony Kelley\n
# 50         Featherweight\n             UFC 252 (UFC APEX) -  Kai Kamaka III\n
# 51          Middleweight\n                                                 \n
# 52          Bantamweight\n                                                 \n
# 53   Women's Strawweight\n                                                 \n
# 54         Featherweight\n                                                 \n
# 55          Middleweight\n          UFC on ESPN 15 (UFC APEX) - Maki Pitolo\n
# 56         Featherweight\n        UFC Fight Night 175 (TBD) -  Timur Valiev\n
#
#       Endeavor record\n    MMA record\n
# 0                 4–4\n          16–5\n
# 1                 4–6\n        17–7–1\n
# 2                12–7\n        24–9–1\n
# 3                 6–7\n         23–10\n
# 4                 2–5\n          12–5\n
# 5                10–5\n          13–5\n
# 6                 7–5\n          13–5\n
# 7                 0–1\n          10–1\n
# 8                 3–3\n           9–3\n
# 9                 Ref\n    MMA record\n
# 10               [20]\n          12–0\n
# 11                   \n        31–9–1\n
# 12                   \n         6–0–2\n
# 13                   \n          18–7\n
# 14               [25]\n          19–6\n
# 15               [27]\n           5–0\n
# 16       [29]\n[30]\n\n          12–3\n
# 17               [32]\n    6–1 (1 NC)\n
# 18               [34]\n          12–0\n
# 19              <[36]\n           9–4\n
# 20               [38]\n           7–2\n
# 21                   \n          16–6\n
# 22               [41]\n           9–0\n
# 23               [43]\n          11–0\n
# 24                   \n  8–0–1 (2 NC)\n
# 25                   \n          10–0\n
# 26               [46]\n          12–0\n
# 27               [48]\n          10–2\n
# 28               [50]\n          15–4\n
# 29               [52]\n          10–1\n
# 30               [54]\n           7–2\n
# 31               [56]\n           8–2\n
# 32               [58]\n         26–13\n
# 33                   \n          11–1\n
# 34               [61]\n           8–1\n
# 35               [62]\n    8–0 (1 NC)\n
# 36               [64]\n   16–4 (1 NC)\n
# 37               [65]\n           8–0\n
# 38               [67]\n          16–2\n
# 39                   \n          11–2\n
# 40  TJ Brown vs. [69]\n           9–3\n
# 41               [71]\n           9–4\n
# 42               [73]\n          17–4\n
# 43                   \n          11–5\n
# 44               [74]\n           5–0\n
# 45                   \n           6–0\n
# 46               [76]\n           8–3\n
# 47               [76]\n          10–5\n
# 48               [78]\n           6–2\n
# 49               [80]\n           7–2\n
# 50               [82]\n           4–1\n
# 51                   \n          13–1\n
# 52                   \n          11–3\n
# 53                   \n           5–1\n
# 54                   \n          12–3\n
# 55               [84]\n           7–0\n
# 56               [67]\n   18–2 (1 NC)\n

# %% [markdown]
# ---

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://en.wikipedia.org/wiki/List_of_current_UFC_fighters#Heavyweights_(265_lb,_120_kg)')
soup = BeautifulSoup(r.text, "html.parser")

summary = soup.find_all('table', class_ = "infobox vcard selectorgadget_selected")

print('Summary: {}'.format(summary))
# Out:
# Summary: []
