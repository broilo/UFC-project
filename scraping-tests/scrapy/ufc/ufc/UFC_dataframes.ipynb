# %% [markdown]
# # Scraping data from [UFC-site](ufc.com.br/rankings)
#
# * I'm using a py-code using Scrapy-library

# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# /home/broilo/Documents/GitHub/Dataset/UFC-project/scraping-tests/scrapy/ufc/ufc

# %%
path = '/home/broilo/Documents/GitHub/Dataset/UFC-project/scraping-tests/scrapy/ufc/ufc'
os.chdir(path)

# %%
df_champs = pd.read_csv('champs.csv')

# %%
df_champs
# Out:
#                     category                  champ
# 0     Men's Pound-for-Pound               Jon Jones
# 1                 Peso-mosca    Deiveson Figueiredo
# 2                  Peso-galo               Petr Yan
# 3                  Peso-pena  Alexander Volkanovski
# 4                  Peso-leve    Khabib Nurmagomedov
# 5            Peso Meio-Médio           Kamaru Usman
# 6                 Peso-médio        Israel Adesanya
# 7           Peso meio-pesado              Jon Jones
# 8                Peso-pesado           Stipe Miocic
# 9    Peso Por Peso Feminino            Amanda Nunes
# 10       Peso-palha feminino            Weili Zhang
# 11       Peso-mosca feminino   Valentina Shevchenko
# 12        Peso-galo feminino           Amanda Nunes
# 13        Peso-Pena Feminino           Amanda Nunes

# %%
df_ranks = pd.read_csv('ranks.csv')

# %%
df_ranks
# Out:
#                     category  \
# 0     Men's Pound-for-Pound
# 1                 Peso-mosca
# 2                  Peso-galo
# 3                  Peso-pena
# 4                  Peso-leve
# 5            Peso Meio-Médio
# 6                 Peso-médio
# 7           Peso meio-pesado
# 8                Peso-pesado
# 9    Peso Por Peso Feminino
# 10       Peso-palha feminino
# 11       Peso-mosca feminino
# 12        Peso-galo feminino
# 13        Peso-Pena Feminino
#
#                                                  rank
# 0   Khabib Nurmagomedov,Stipe Miocic,Israel Adesan...
# 1   Joseph Benavidez,Brandon Moreno,Askar Askarov,...
# 2   Marlon Moraes,Aljamain Sterling,Cody Garbrandt...
# 3   Max Holloway,Brian Ortega,Zabit Magomedsharipo...
# 4   Justin Gaethje,Dustin Poirier,Tony Ferguson,Co...
# 5   Gilbert Burns,Colby Covington,Leon Edwards,Jor...
# 6   Robert Whittaker,Paulo Costa,Jared Cannonier,J...
# 7   Dominick Reyes,Thiago Santos,Jan Blachowicz,Gl...
# ...

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test
# Out:
#                     category                  champ  \
# 0     Men's Pound-for-Pound               Jon Jones
# 1                 Peso-mosca    Deiveson Figueiredo
# 2                  Peso-galo               Petr Yan
# 3                  Peso-pena  Alexander Volkanovski
# 4                  Peso-leve    Khabib Nurmagomedov
# 5            Peso Meio-Médio           Kamaru Usman
# 6                 Peso-médio        Israel Adesanya
# 7           Peso meio-pesado              Jon Jones
# 8                Peso-pesado           Stipe Miocic
# 9    Peso Por Peso Feminino            Amanda Nunes
# 10       Peso-palha feminino            Weili Zhang
# 11       Peso-mosca feminino   Valentina Shevchenko
# 12        Peso-galo feminino           Amanda Nunes
# 13        Peso-Pena Feminino           Amanda Nunes
#
#                                                  rank
# 0   Khabib Nurmagomedov,Stipe Miocic,Israel Adesan...
# 1   Joseph Benavidez,Brandon Moreno,Askar Askarov,...
# ...
